# %% [markdown]
# # Exercise 02 : Preprocessing
# ## Required data

# %%
# %ls ../data/auto.csv
# Out:
# ../data/auto.csv

# %% [markdown]
# ## Code

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('../data/auto.csv',
                 index_col='ID'
                )
df
# Out:
#         CarNumber    Make_n_model  Refund    Fines  History
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.0      NaN
# 1     E432XX77RUS    Toyota Camry     1.0   6500.0      NaN
# 2     7184TT36RUS      Ford Focus     1.0   2100.0      NaN
# 3    X582HE161RUS      Ford Focus     2.0   2000.0      NaN
# 4    E34877152RUS      Ford Focus     2.0   6100.0      NaN
# ..            ...             ...     ...      ...      ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.0      NaN
# 927  M0309X197RUS      Ford Focus     1.0  22300.0      NaN
# 928  O673E8197RUS      Ford Focus     2.0    600.0      NaN
# 929  8610T8154RUS      Ford Focus     1.0   2000.0      NaN
# 930  H419XE197RUS  Toyota Corolla     2.0      NaN      2.0
#
# [931 rows x 5 columns]

# %%
df.count()[0]
# Out:
# 931

# %% [markdown]
# ### Drop duplicates by CarNumber, Make_n_model and Fines

# %%
df.drop_duplicates(subset=['CarNumber', 'Make_n_model', 'Fines'],
                        keep='last',
                        inplace=True
                       )

df
# Out:
#         CarNumber    Make_n_model  Refund    Fines  History
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.0      NaN
# 1     E432XX77RUS    Toyota Camry     1.0   6500.0      NaN
# 2     7184TT36RUS      Ford Focus     1.0   2100.0      NaN
# 3    X582HE161RUS      Ford Focus     2.0   2000.0      NaN
# 5    92918M178RUS      Ford Focus     1.0   5700.0      NaN
# ..            ...             ...     ...      ...      ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.0      NaN
# 927  M0309X197RUS      Ford Focus     1.0  22300.0      NaN
# 928  O673E8197RUS      Ford Focus     2.0    600.0      NaN
# 929  8610T8154RUS      Ford Focus     1.0   2000.0      NaN
# 930  H419XE197RUS  Toyota Corolla     2.0      NaN      2.0
#
# [725 rows x 5 columns]

# %%
df.count()[0]
# Out:
# 725

# %% [markdown]
# ### Work with missing values
# #### Count NaN values in each column

# %%
df.isna().sum(axis='index')
# Out:
# CarNumber         0
# Make_n_model      0
# Refund           12
# Fines            60
# History         660
# dtype: int64

# %% [markdown]
# #### Drop column with over 500 missing values

# %%
df.dropna(axis='columns',
          thresh=df.count()[0] - 500,
          inplace=True
         )

df
# Out:
#         CarNumber    Make_n_model  Refund    Fines
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.0
# 1     E432XX77RUS    Toyota Camry     1.0   6500.0
# 2     7184TT36RUS      Ford Focus     1.0   2100.0
# 3    X582HE161RUS      Ford Focus     2.0   2000.0
# 5    92918M178RUS      Ford Focus     1.0   5700.0
# ..            ...             ...     ...      ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.0
# 927  M0309X197RUS      Ford Focus     1.0  22300.0
# 928  O673E8197RUS      Ford Focus     2.0    600.0
# 929  8610T8154RUS      Ford Focus     1.0   2000.0
# 930  H419XE197RUS  Toyota Corolla     2.0      NaN
#
# [725 rows x 4 columns]

# %%
df.isna().sum(axis='index')
# Out:
# CarNumber        0
# Make_n_model     0
# Refund          12
# Fines           60
# dtype: int64

# %% [markdown]
# ####  Replace all the missing values in the Refund column with the previous value in that column for that cell

# %%
df['Refund'].fillna(
    method='ffill',
    inplace=True
)

df
# Out:
#         CarNumber    Make_n_model  Refund    Fines
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.0
# 1     E432XX77RUS    Toyota Camry     1.0   6500.0
# 2     7184TT36RUS      Ford Focus     1.0   2100.0
# 3    X582HE161RUS      Ford Focus     2.0   2000.0
# 5    92918M178RUS      Ford Focus     1.0   5700.0
# ..            ...             ...     ...      ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.0
# 927  M0309X197RUS      Ford Focus     1.0  22300.0
# 928  O673E8197RUS      Ford Focus     2.0    600.0
# 929  8610T8154RUS      Ford Focus     1.0   2000.0
# 930  H419XE197RUS  Toyota Corolla     2.0      NaN
#
# [725 rows x 4 columns]

# %%
df.isna().sum(axis='index')
# Out:
# CarNumber        0
# Make_n_model     0
# Refund           0
# Fines           60
# dtype: int64

# %% [markdown]
# #### Replace all the missing values in the Fines column with the mean value of this column

# %%
mean_value = df['Fines'].mean(skipna=True)
mean_value
# Out:
# 8594.586466165414

# %%
df['Fines'].fillna(
    value=mean_value,
    inplace=True
)

df
# Out:
#         CarNumber    Make_n_model  Refund         Fines
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.000000
# 1     E432XX77RUS    Toyota Camry     1.0   6500.000000
# 2     7184TT36RUS      Ford Focus     1.0   2100.000000
# 3    X582HE161RUS      Ford Focus     2.0   2000.000000
# 5    92918M178RUS      Ford Focus     1.0   5700.000000
# ..            ...             ...     ...           ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.000000
# 927  M0309X197RUS      Ford Focus     1.0  22300.000000
# 928  O673E8197RUS      Ford Focus     2.0    600.000000
# 929  8610T8154RUS      Ford Focus     1.0   2000.000000
# 930  H419XE197RUS  Toyota Corolla     2.0   8594.586466
#
# [725 rows x 4 columns]

# %%
df.isna().sum(axis='index')
# Out:
# CarNumber       0
# Make_n_model    0
# Refund          0
# Fines           0
# dtype: int64

# %% [markdown]
# ### Split and parse the make and model

# %%
df[['Make', 'Model']] = pd.DataFrame(df['Make_n_model'].apply(str.split).tolist(),
                                     index=df.index
                                    )
df
# Out:
#         CarNumber    Make_n_model  Refund         Fines    Make    Model
# ID
# 0    Y163O8161RUS      Ford Focus     2.0   3200.000000    Ford    Focus
# 1     E432XX77RUS    Toyota Camry     1.0   6500.000000  Toyota    Camry
# 2     7184TT36RUS      Ford Focus     1.0   2100.000000    Ford    Focus
# 3    X582HE161RUS      Ford Focus     2.0   2000.000000    Ford    Focus
# 5    92918M178RUS      Ford Focus     1.0   5700.000000    Ford    Focus
# ..            ...             ...     ...           ...     ...      ...
# 926  Y163O8161RUS      Ford Focus     2.0   1600.000000    Ford    Focus
# 927  M0309X197RUS      Ford Focus     1.0  22300.000000    Ford    Focus
# 928  O673E8197RUS      Ford Focus     2.0    600.000000    Ford    Focus
# 929  8610T8154RUS      Ford Focus     1.0   2000.000000    Ford    Focus
# 930  H419XE197RUS  Toyota Corolla     2.0   8594.586466  Toyota  Corolla
#
# [725 rows x 6 columns]

# %%
df.drop('Make_n_model', 
        axis='columns', 
        inplace=True
       )
df
# Out:
#         CarNumber  Refund         Fines    Make    Model
# ID
# 0    Y163O8161RUS     2.0   3200.000000    Ford    Focus
# 1     E432XX77RUS     1.0   6500.000000  Toyota    Camry
# 2     7184TT36RUS     1.0   2100.000000    Ford    Focus
# 3    X582HE161RUS     2.0   2000.000000    Ford    Focus
# 5    92918M178RUS     1.0   5700.000000    Ford    Focus
# ..            ...     ...           ...     ...      ...
# 926  Y163O8161RUS     2.0   1600.000000    Ford    Focus
# 927  M0309X197RUS     1.0  22300.000000    Ford    Focus
# 928  O673E8197RUS     2.0    600.000000    Ford    Focus
# 929  8610T8154RUS     1.0   2000.000000    Ford    Focus
# 930  H419XE197RUS     2.0   8594.586466  Toyota  Corolla
#
# [725 rows x 5 columns]

# %% [markdown]
# ### Save the dataframe in the JSON file

# %%
df.to_json('auto.json',
           orient='records'
          )

# %%
# %cat auto.json
# Out:
# [{"CarNumber":"Y163O8161RUS","Refund":2.0,"Fines":3200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"E432XX77RUS","Refund":1.0,"Fines":6500.0,"Make":"Toyota","Model":"Camry"},{"CarNumber":"7184TT36RUS","Refund":1.0,"Fines":2100.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"X582HE161RUS","Refund":2.0,"Fines":2000.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"92918M178RUS","Refund":1.0,"Fines":5700.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"H234YH197RUS","Refund":2.0,"Fines":6000.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"E40577152RUS","Refund":1.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"707987163RUS","Refund":2.0,"Fines":2200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"K330T8197RUS","Refund":2.0,"Fines":8200.0,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"X786CO96RUS","Refund":1.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"C477M7161RUS","Refund":1.0,"Fines":2500.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"O21997197RUS","Refund":1.0,"Fines":2000.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"M592CH197RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"9020YC197RUS","Refund":2.0,"Fines":145000.0,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"8182XX154RUS","Refund":1.0,"Fines":200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"7830C8197RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"7066C8197RUS","Refund":2.0,"Fines":15000.0,"Make":"Volkswagen","Model":"Passat"},{"CarNumber":"M298CH161RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"E445TC197RUS","Refund":1.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"8440XX154RUS","Refund":1.0,"Fines":6200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"9371CE154RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"9182CE154RUS","Refund":2.0,"Fines":19800.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"83298C154RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"Y7659C197RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"C922YE197RUS","Refund":2.0,"Fines":3800.0,"Make":"Volkswagen","Model":"Golf"},{"CarNumber":"7364C8197RUS","Refund":2.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"M5039X197RUS","Refund":2.0,"Fines":7400.0,"Make":"Volkswagen","Model":null},{"CarNumber":"8603T8154RUS","Refund":1.0,"Fines":1500.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"92928M178RUS","Refund":1.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"O672E8197RUS","Refund":2.0,"Fines":63300.0,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"E42277152RUS","Refund":2.0,"Fines":10600.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"C903MC161RUS","Refund":1.0,"Fines":1600.0,"Make":"Volkswagen","Model":"Jetta"},{"CarNumber":"T7318T163RUS","Refund":2.0,"Fines":12000.0,"Make":"Toyota","Model":"Camry"},{"CarNumber":"Y7719C197RUS","Refund":1.0,"Fines":9200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"T011MY163RUS","Refund":1.0,"Fines":2000.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"H115YO163RUS","Refund":1.0,"Fines":2200.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"73467Y96RUS","Refund":1.0,"Fines":800.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"O134HE197RUS","Refund":1.0,"Fines":8594.5864661654,"Make":"Ford","Model":"Focus"},{"CarNumber":"H968HY161RUS","Refund":1.0,"Fines":2400.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"Y654E8750RUS","Refund":1.0,"Fines":500.0,"Make":"Skoda","Model":"Octavia"},{"CarNumber":"H963HY161RUS","Refund":2.0,"Fines":2800.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"H232YH197RUS","Refund":2.0,"Fines":8600.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"7843C8197RUS","Refund":2.0,"Fines":12300.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"X791O796RUS","Refund":1.0,"Fines":500.0,"Make":"Ford","Model":"Focus"},{"CarNumber":"H958HY1 ...
