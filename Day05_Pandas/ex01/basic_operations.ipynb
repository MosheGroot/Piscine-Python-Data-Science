# %% [markdown]
# # Exercise 01 : Basic operations
# ## Required data

# %%
# %ls ../data/feed-views.log
# Out:
# ../data/feed-views.log

# %% [markdown]
# ## Code

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Read data

# %%
data_df = pd.read_csv('../data/feed-views.log',
                      sep='\t',
                      names=('datetime', 'user'),
                     )
data_df
# Out:
#                         datetime       user
# 0     2020-04-17 12:01:08.463179      artem
# 1     2020-04-17 12:01:23.743946      artem
# 2     2020-04-17 12:27:30.646665      artem
# 3     2020-04-17 12:35:44.884757      artem
# 4     2020-04-17 12:35:52.735016      artem
# ...                          ...        ...
# 1071  2020-05-21 18:45:20.441142  valentina
# 1072  2020-05-21 23:03:06.457819      maxim
# 1073  2020-05-21 23:23:49.995349      pavel
# 1074  2020-05-21 23:49:22.386789      artem
# 1075  2020-05-22 10:36:14.662600      artem
#
# [1076 rows x 2 columns]

# %% [markdown]
# ### Convert datetime column to datetime64[ns] Dtype and split datetime to columns

# %%
data_df['datetime'] = pd.to_datetime(data_df['datetime'])

data_df['year'] = pd.DatetimeIndex(data_df['datetime']).year
data_df['month'] = pd.DatetimeIndex(data_df['datetime']).month
data_df['day'] = pd.DatetimeIndex(data_df['datetime']).day
data_df['hour'] = pd.DatetimeIndex(data_df['datetime']).hour
data_df['minute'] = pd.DatetimeIndex(data_df['datetime']).minute
data_df['second'] = pd.DatetimeIndex(data_df['datetime']).second

# %%
data_df
# Out:
#                        datetime       user  year  month  day  hour  minute  \
# 0    2020-04-17 12:01:08.463179      artem  2020      4   17    12       1
# 1    2020-04-17 12:01:23.743946      artem  2020      4   17    12       1
# 2    2020-04-17 12:27:30.646665      artem  2020      4   17    12      27
# 3    2020-04-17 12:35:44.884757      artem  2020      4   17    12      35
# 4    2020-04-17 12:35:52.735016      artem  2020      4   17    12      35
# ...                         ...        ...   ...    ...  ...   ...     ...
# 1071 2020-05-21 18:45:20.441142  valentina  2020      5   21    18      45
# 1072 2020-05-21 23:03:06.457819      maxim  2020      5   21    23       3
# 1073 2020-05-21 23:23:49.995349      pavel  2020      5   21    23      23
# 1074 2020-05-21 23:49:22.386789      artem  2020      5   21    23      49
# 1075 2020-05-22 10:36:14.662600      artem  2020      5   22    10      36
#
#       second
# 0          8
# 1         23
# 2         30
# ...

# %% [markdown]
# ### Daytime column

# %%
data_df['daytime'] = pd.cut(data_df['hour'],
                            bins=[-1, 3, 6, 10, 16, 19, 24],
                            labels=['night', 'early morning', 'morning', 'afternoon', 'early evening', 'evening']
                           )

# %%
data_df
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# valentina 2020-05-15 00:00:13.222265  2020      5   15     0       0      13
# valentina 2020-05-15 00:01:05.153738  2020      5   15     0       1       5
# pavel     2020-05-12 00:01:27.764025  2020      5   12     0       1      27
# pavel     2020-05-12 00:01:38.444917  2020      5   12     0       1      38
# pavel     2020-05-12 00:01:55.395042  2020      5   12     0       1      55
# ...                              ...   ...    ...  ...   ...     ...     ...
# artem     2020-05-21 23:49:22.386789  2020      5   21    23      49      22
# anatoliy  2020-05-09 23:53:55.599821  2020      5    9    23      53      55
# pavel     2020-05-09 23:54:54.260791  2020      5    9    23      54      54
# valentina 2020-05-14 23:58:56.754866  2020      5   14    23      58      56
# alexander 2020-05-14 23:59:38.758438  2020      5   14    23      59      38
#
#            daytime
# user
# ...

# %% [markdown]
# ### Assign the column user as the index (why?)

# %%
data_df.set_index('user', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 data_df.set_index('user', inplace=True)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# ...

# %%
data_df
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# valentina 2020-05-15 00:00:13.222265  2020      5   15     0       0      13
# valentina 2020-05-15 00:01:05.153738  2020      5   15     0       1       5
# pavel     2020-05-12 00:01:27.764025  2020      5   12     0       1      27
# pavel     2020-05-12 00:01:38.444917  2020      5   12     0       1      38
# pavel     2020-05-12 00:01:55.395042  2020      5   12     0       1      55
# ...                              ...   ...    ...  ...   ...     ...     ...
# artem     2020-05-21 23:49:22.386789  2020      5   21    23      49      22
# anatoliy  2020-05-09 23:53:55.599821  2020      5    9    23      53      55
# pavel     2020-05-09 23:54:54.260791  2020      5    9    23      54      54
# valentina 2020-05-14 23:58:56.754866  2020      5   14    23      58      56
# alexander 2020-05-14 23:59:38.758438  2020      5   14    23      59      38
#
#            daytime
# user
# ...

# %% [markdown]
# ### Counts

# %%
data_df.count(axis='index')
# Out:
# datetime    1076
# year        1076
# month       1076
# day         1076
# hour        1076
# minute      1076
# second      1076
# daytime     1076
# dtype: int64

# %%
data_df['daytime'].value_counts()
# Out:
# evening          509
# afternoon        252
# early evening    145
# night            129
# morning           36
# early morning      5
# Name: daytime, dtype: int64

# %% [markdown]
# ### Sort by hour, minute, and second in ascending order

# %%
data_df = data_df.sort_values(by=['hour', 'minute', 'second'])

# %%
data_df
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# valentina 2020-05-15 00:00:13.222265  2020      5   15     0       0      13
# valentina 2020-05-15 00:01:05.153738  2020      5   15     0       1       5
# pavel     2020-05-12 00:01:27.764025  2020      5   12     0       1      27
# pavel     2020-05-12 00:01:38.444917  2020      5   12     0       1      38
# pavel     2020-05-12 00:01:55.395042  2020      5   12     0       1      55
# ...                              ...   ...    ...  ...   ...     ...     ...
# artem     2020-05-21 23:49:22.386789  2020      5   21    23      49      22
# anatoliy  2020-05-09 23:53:55.599821  2020      5    9    23      53      55
# pavel     2020-05-09 23:54:54.260791  2020      5    9    23      54      54
# valentina 2020-05-14 23:58:56.754866  2020      5   14    23      58      56
# alexander 2020-05-14 23:59:38.758438  2020      5   14    23      59      38
#
#            daytime
# user
# ...

# %% [markdown]
# ### Calculate the maximum of hour for the rows where the time of day is night

# %%
max_night_hour = (data_df['hour'].loc[data_df['daytime'] == 'night']).max()
max_night_hour
# Out:
# 3

# %% [markdown]
# ### Calculate the minimum of hour for the rows where the time of day is morning

# %%
min_morning_hour = (data_df['hour'].loc[data_df['daytime'] == 'morning']).min()
min_morning_hour
# Out:
# 8

# %% [markdown]
# ### Find out who visited the page at those hours

# %%
data_df.loc[data_df['hour'] == max_night_hour]
# Out:
#                              datetime  year  month  day  hour  minute  second  \
# user
# konstantin 2020-04-19 03:23:35.471598  2020      4   19     3      23      35
# konstantin 2020-04-19 03:23:55.473926  2020      4   19     3      23      55
# konstantin 2020-04-19 03:33:07.757714  2020      4   19     3      33       7
#
#            daytime
# user
# konstantin   night
# konstantin   night
# konstantin   night

# %%
data_df.loc[data_df['hour'] == min_morning_hour]
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# alexander 2020-05-15 08:16:03.918402  2020      5   15     8      16       3
# alexander 2020-05-15 08:35:01.471463  2020      5   15     8      35       1
#
#            daytime
# user
# alexander  morning
# alexander  morning

# %% [markdown]
# ### Calculate the mode for the hour and daytime

# %%
data_df['hour'].mode()
# Out:
# 0    22
# Name: hour, dtype: int64

# %%
data_df['daytime'].mode()
# Out:
# 0    evening
# Name: daytime, dtype: category
# Categories (6, object): ['night' < 'early morning' < 'morning' < 'afternoon' < 'early evening' < 'evening']

# %% [markdown]
# ### 3 earliest hours in the morning and the corresponding usernames

# %%
data_df.loc[data_df['daytime'] == 'morning'].nsmallest(3, columns=['hour'])['hour']
# Out:
# user
# alexander    8
# alexander    8
# alexander    9
# Name: hour, dtype: int64

# %% [markdown]
# ### 3 latest hours and the usernames

# %%
data_df.loc[data_df['daytime'] == 'morning'].nlargest(3, columns=['hour'])['hour']
# Out:
# user
# konstantin    10
# maxim         10
# maxim         10
# Name: hour, dtype: int64

# %% [markdown]
# ### Get the basic statistics for the columns

# %%
data_describe = data_df.describe()
data_describe
# Out:
#          year        month          day         hour       minute       second
# count  1076.0  1076.000000  1076.000000  1076.000000  1076.000000  1076.000000
# mean   2020.0     4.870818    13.552974    16.249071    29.629182    29.500929
# std       0.0     0.335557     4.906567     6.955490    17.689388    17.405506
# min    2020.0     4.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2020.0     5.000000    11.000000    13.000000    14.000000    14.000000
# 50%    2020.0     5.000000    13.000000    19.000000    29.000000    30.000000
# 75%    2020.0     5.000000    15.000000    22.000000    46.000000    45.000000
# max    2020.0     5.000000    30.000000    23.000000    59.000000    59.000000

# %% [markdown]
# ### Interquartile range for the hour

# %%
iqr = data_describe['hour']['75%'] - data_describe['hour']['25%']
iqr
# Out:
# 9.0
